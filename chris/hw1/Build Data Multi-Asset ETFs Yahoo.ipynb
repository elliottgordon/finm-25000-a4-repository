# %%
import pandas as pd
import numpy as np
import time
import yfinance as yf

# %%
TICKS = [
    'SPY',
    'EFA',
    'EEM',
    'PSP',
    'QAI',
    'HYG',
    'DBC',
    'IYR',
    'IEF',
    'BWX',
    'TIP',
    'SHV',
]

FLDS = ['shortName','quoteType','currency','volume','totalAssets','longBusinessSummary']

# %%
info = pd.DataFrame(index=TICKS,columns=FLDS)
info.index.name = 'ticker'
for tick in info.index:
    temp = yf.Ticker(tick).get_info()

    for fld in FLDS:
        if fld in temp.keys():
            info.loc[tick,fld] = temp[fld]
    
    # time.sleep(1)
# Out:
# HTTP Error 401:
# HTTP Error 401:
# HTTP Error 401:
# HTTP Error 401:
# HTTP Error 401:

# %%
info
# Out:
#                               shortName quoteType currency    volume  \
# ticker
# SPY                        SPDR S&P 500       ETF      USD       NaN
# EFA               iShares MSCI EAFE ETF       ETF      USD  15707939
# EEM     iShares MSCI Emerging Index Fun       ETF      USD       NaN
# PSP     Invesco Global Listed Private E       ETF      USD       NaN
# QAI     NYLI Hedge Multi-Strategy Track       ETF      USD       NaN
# HYG     iShares iBoxx $ High Yield Corp       ETF      USD  44876836
# DBC     Invesco DB Commodity Index Trac       ETF      USD    989890
# IYR        iShares U.S. Real Estate ETF       ETF      USD   5587505
# IEF     iShares 7-10 Year Treasury Bond       ETF      USD   6260724
# BWX     SPDR Bloomberg International Tr       ETF      USD    171984
# TIP               iShares TIPS Bond ETF       ETF      USD       NaN
# SHV     iShares Short Treasury Bond ETF       ETF      USD   2150076
#
#         totalAssets                                longBusinessSummary
# ticker
# SPY             NaN                                                NaN
# EFA     63209721856  The fund generally will invest at least 80% of...
# EEM             NaN                                                NaN
# PSP             NaN                                                NaN
# QAI             NaN                                                NaN
# HYG     15944028160  The underlying index is a rules-based index co...
# DBC      1142769792  The fund pursues its investment objective by i...
# IYR      3480166144  The fund seeks to track the investment results...
# IEF     34938195968  The underlying index measures the performance ...
# BWX      1423427840  The fund generally invests substantially all, ...
# TIP             NaN                                                NaN
# SHV     20599980032  The fund will invest at least 80% of its asset...

# %%
STARTDATE = '2011-01-01'
ENDDATE = '2025-05-31'

tickers = list(info.index.values)
print(tickers)
df = yf.download(tickers, start=STARTDATE, end=ENDDATE)['Close']
df
# Out:
# ['SPY', 'EFA', 'EEM', 'PSP', 'QAI', 'HYG', 'DBC', 'IYR', 'IEF', 'BWX', 'TIP', 'SHV']
# /var/folders/wr/nq689hr13ys6b7lc9zzpmbl00000gn/T/ipykernel_44861/3265531318.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(tickers, start=STARTDATE, end=ENDDATE)['Close']
# [*********************100%***********************]  12 of 12 completed
# Ticker            BWX        DBC        EEM        EFA        HYG        IEF  \
# Date
# 2011-01-03  24.144175  24.180582  35.192905  38.008770  40.534435  69.310127
# 2011-01-04  24.028496  23.857241  35.353874  37.892212  40.718376  69.473145
# 2011-01-05  23.685566  24.110672  35.266079  37.730347  40.821526  68.724686
# 2011-01-06  23.536844  23.787331  34.892918  37.296505  40.870895  69.080429
# 2011-01-07  23.433552  23.699942  34.570999  37.147591  40.713837  69.539848
# ...               ...        ...        ...        ...        ...        ...
# 2025-05-23  22.907982  21.410000  45.786442  86.541260  78.576927  93.462616
# 2025-05-27  22.868055  21.219999  45.677498  87.799469  79.054665  93.851349
# 2025-05-28  22.778219  21.150000  45.469513  86.787003  79.004898  93.592194
# 2025-05-29  22.937925  21.040001  45.637886  87.170364  79.124329  93.980919
# 2025-05-30  22.898001  20.879999  45.083256  87.298149  79.194000  94.259995
#
# Ticker            IYR        PSP        QAI         SHV         SPY  \
# Date
# 2011-01-03  35.116604  22.196001  22.510592   91.496582   97.750336
# 2011-01-04  34.492504  22.114397  22.469547   91.504868   97.696465
# 2011-01-05  34.634632  22.236801  22.494175   91.504868   98.204269
# 2011-01-06  34.449238  22.053196  22.436708   91.504868   98.011948
# 2011-01-07  34.436897  21.991993  22.502384   91.504868   97.819572
# ...               ...        ...        ...         ...         ...
# 2025-05-23  91.729843  65.650002  31.760000  109.983215  577.403015
# 2025-05-27  93.241928  67.029999  31.969999  109.983215  589.407593
# 2025-05-28  93.132500  66.489998  31.809999  109.993179  585.997620
# 2025-05-29  93.948227  66.739998  31.840000  110.023071  588.310791
# 2025-05-30  94.047707  66.470001  31.830000  110.043007  587.652771
#
# Ticker             TIP
# Date
# 2011-01-03   74.706825
# 2011-01-04   74.895241
# 2011-01-05   74.609215
# 2011-01-06   74.825455
# 2011-01-07   75.062698
# ...                ...
# 2025-05-23  108.288826
# 2025-05-27  108.598053
# 2025-05-28  108.348679
# 2025-05-29  108.657906
# 2025-05-30  109.017006
#
# [3624 rows x 12 columns]

# %%
prices = df.resample('M').last()

# eliminate timezones
prices.index = prices.index.tz_localize(None)

rets = prices.pct_change().dropna()
rets['SHV'] -= .01/20

# change to excess returns, in excess of short-term treasury
retsx = rets.subtract(rets['SHV'], axis=0)
retsx = retsx.drop(columns=['SHV'])
# Out:
# /var/folders/wr/nq689hr13ys6b7lc9zzpmbl00000gn/T/ipykernel_41169/1814017950.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   prices = df.resample('M').last()

# %%
rets
# Out:
# Ticker           BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2011-02-28  0.006617  0.041710 -0.000437  0.035498  0.014355 -0.002084
# 2011-03-31  0.008427  0.026582  0.062896 -0.023883  0.000424 -0.001546
# 2011-04-30  0.048806  0.045559  0.027327  0.056258  0.015976  0.018413
# 2011-05-31 -0.013546 -0.051724 -0.029400 -0.022061  0.001333  0.025056
# 2011-06-30 -0.000097 -0.042645 -0.009355 -0.012108 -0.005706 -0.005044
# ...              ...       ...       ...       ...       ...       ...
# 2025-01-31  0.000935  0.027596  0.021521  0.048009  0.013605  0.006165
# 2025-02-28  0.013991  0.001366  0.011470  0.029531  0.009703  0.027997
# 2025-03-31  0.010353  0.022727  0.011340  0.001839 -0.010858  0.003419
# 2025-04-30  0.057697 -0.085778  0.001373  0.036951  0.001172  0.010561
# 2025-05-31 -0.004599  0.015070  0.040219  0.047906  0.017532 -0.012396
#
# Ticker           IYR       PSP       QAI       SHV       SPY       TIP
# Date
# 2011-02-28  0.045204  0.040146  0.002583 -0.000409  0.034737  0.007208
# 2011-03-31 -0.010935  0.016666  0.005521 -0.000328  0.000120  0.011903
# 2011-04-30  0.046634  0.058672  0.019034  0.000045  0.028961  0.023780
# 2011-05-31  0.010133 -0.041565  0.000000 -0.000600 -0.011215  0.002659
# 2011-06-30 -0.031060 -0.042581 -0.010776 -0.000328 -0.016869  0.007550
# ...              ...       ...       ...       ...       ...       ...
# 2025-01-31  0.018913  0.067995  0.016237  0.003133  0.026856  0.013703
# 2025-02-28  0.037861 -0.040107 -0.005952  0.002615 -0.012695  0.021572
# 2025-03-31 -0.023382 -0.060826 -0.013237  0.002843 -0.055719  0.006797
# 2025-04-30 -0.021514 -0.006867 -0.002555  0.002988 -0.008670  0.001259
# 2025-05-31  0.009072  0.044633  0.019212  0.002698  0.062845 -0.006319
#
# [172 rows x 12 columns]

# %%
retsx
# Out:
# Ticker           BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2011-02-28  0.007027  0.042120 -0.000027  0.035908  0.014764 -0.001674
# 2011-03-31  0.008755  0.026909  0.063224 -0.023555  0.000752 -0.001219
# 2011-04-30  0.048761  0.045514  0.027282  0.056213  0.015931  0.018368
# 2011-05-31 -0.012947 -0.051124 -0.028800 -0.021461  0.001933  0.025655
# 2011-06-30  0.000231 -0.042317 -0.009027 -0.011779 -0.005378 -0.004716
# ...              ...       ...       ...       ...       ...       ...
# 2025-01-31 -0.002198  0.024463  0.018388  0.044877  0.010472  0.003033
# 2025-02-28  0.011376 -0.001250  0.008855  0.026916  0.007087  0.025382
# 2025-03-31  0.007511  0.019885  0.008497 -0.001004 -0.013701  0.000577
# 2025-04-30  0.054708 -0.088766 -0.001616  0.033963 -0.001817  0.007573
# 2025-05-31 -0.007297  0.012373  0.037522  0.045208  0.014835 -0.015094
#
# Ticker           IYR       PSP       QAI       SPY       TIP
# Date
# 2011-02-28  0.045613  0.040556  0.002992  0.035147  0.007617
# 2011-03-31 -0.010608  0.016994  0.005848  0.000448  0.012230
# 2011-04-30  0.046589  0.058627  0.018989  0.028916  0.023735
# 2011-05-31  0.010733 -0.040966  0.000600 -0.010615  0.003259
# 2011-06-30 -0.030732 -0.042253 -0.010448 -0.016541  0.007878
# ...              ...       ...       ...       ...       ...
# 2025-01-31  0.015780  0.064862  0.013104  0.023724  0.010570
# 2025-02-28  0.035246 -0.042722 -0.008567 -0.015310  0.018957
# 2025-03-31 -0.026225 -0.063669 -0.016079 -0.058562  0.003955
# 2025-04-30 -0.024503 -0.009856 -0.005544 -0.011659 -0.001729
# 2025-05-31  0.006375  0.041935  0.016515  0.060147 -0.009017
#
# [172 rows x 11 columns]

# %%
with pd.ExcelWriter('../data/multi_asset_etf_data.xlsx') as writer:  
    info.to_excel(writer, sheet_name= 'descriptions')
    prices.to_excel(writer, sheet_name= 'prices')
    rets.to_excel(writer, sheet_name='total returns')
    retsx.to_excel(writer, sheet_name='excess returns')
