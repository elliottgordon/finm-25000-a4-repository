# %%
# !pip install pandas numpy yfinance
# Out:
# Collecting pandas
#   Using cached pandas-2.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy
#   Using cached numpy-2.3.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting yfinance
#   Using cached yfinance-0.2.63-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/elliottgordon/Documents/UChicago/Summer 2025/FINM 25000/finm-25000-a4-repository/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting requests>=2.31 (from yfinance)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/elliottgordon/Documents/UChicago/Summer 2025/FINM 25000/finm-25000-a4-repository/.venv/lib/python3.13/site-packages (from yfinance) (4.3.8)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.18.1-cp313-cp313-macosx_15_0_arm64.whl
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Using cached curl_cffi-0.11.4-cp39-abi3-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Using cached cffi-1.17.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi>=0.7->yfinance)
#   Using cached certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in /Users/elliottgordon/Documents/UChicago/Summer 2025/FINM 25000/finm-25000-a4-repository/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Using cached charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Using cached pandas-2.3.0-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
# Using cached numpy-2.3.1-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
# Using cached yfinance-0.2.63-py2.py3-none-any.whl (118 kB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached curl_cffi-0.11.4-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Using cached certifi-2025.6.15-py3-none-any.whl (157 kB)
# Using cached cffi-1.17.1-cp313-cp313-macosx_11_0_arm64.whl (178 kB)
# Using cached frozendict-2.4.6-py313-none-any.whl (16 kB)
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Using cached protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl (199 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pytz, peewee, multitasking, websockets, urllib3, tzdata, typing-extensions, soupsieve, pycparser, protobuf, numpy, idna, frozendict, charset_normalizer, certifi, requests, pandas, cffi, beautifulsoup4, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [yfinance]/21 [curl_cffi]
# Successfully installed beautifulsoup4-4.13.4 certifi-2025.6.15 cffi-1.17.1 charset_normalizer-3.4.2 curl_cffi-0.11.4 frozendict-2.4.6 idna-3.10 multitasking-0.0.11 numpy-2.3.1 pandas-2.3.0 peewee-3.18.1 protobuf-6.31.1 pycparser-2.22 pytz-2025.2 requests-2.32.4 soupsieve-2.7 typing-extensions-4.14.0 tzdata-2025.2 urllib3-2.5.0 websockets-15.0.1 yfinance-0.2.63

# %%
import pandas as pd
import numpy as np
import time
import yfinance as yf

# %%
TICKS = [
    'SPY',
    'EFA',
    'EEM',
    'PSP',
    'QAI',
    'HYG',
    'DBC',
    'IYR',
    'IEF',
    'BWX',
    'TIP',
    'SHV',
]

FLDS = ['shortName','quoteType','currency','volume','totalAssets','longBusinessSummary']

# %%
info = pd.DataFrame(index=TICKS,columns=FLDS)
info.index.name = 'ticker'
for tick in info.index:
    temp = yf.Ticker(tick).get_info()

    for fld in FLDS:
        if fld in temp.keys():
            info.loc[tick,fld] = temp[fld]
    
    #time.sleep(0.5)
# Out:
# HTTP Error 401:
# HTTP Error 401:
# HTTP Error 401:
# HTTP Error 401:
# HTTP Error 401:

# %%
info
# Out:
#                               shortName quoteType currency    volume  \
# ticker
# SPY                        SPDR S&P 500       ETF      USD  93588653
# EFA               iShares MSCI EAFE ETF       ETF      USD       NaN
# EEM     iShares MSCI Emerging Index Fun       ETF      USD  32462175
# PSP     Invesco Global Listed Private E       ETF      USD       NaN
# QAI     NYLI Hedge Multi-Strategy Track       ETF      USD     21639
# HYG     iShares iBoxx $ High Yield Corp       ETF      USD  44876836
# DBC     Invesco DB Commodity Index Trac       ETF      USD    989890
# IYR        iShares U.S. Real Estate ETF       ETF      USD       NaN
# IEF     iShares 7-10 Year Treasury Bond       ETF      USD       NaN
# BWX     SPDR Bloomberg International Tr       ETF      USD    171984
# TIP               iShares TIPS Bond ETF       ETF      USD       NaN
# SHV     iShares Short Treasury Bond ETF       ETF      USD   2150076
#
#          totalAssets                                longBusinessSummary
# ticker
# SPY     603516960768  The trust seeks to achieve its investment obje...
# EFA              NaN                                                NaN
# EEM      17162833920  The fund generally will invest at least 80% of...
# PSP              NaN                                                NaN
# QAI        696944896  The fund is a "fund of funds" which means it i...
# HYG      15944028160  The underlying index is a rules-based index co...
# DBC       1142769792  The fund pursues its investment objective by i...
# IYR              NaN                                                NaN
# IEF              NaN                                                NaN
# BWX       1423427840  The fund generally invests substantially all, ...
# TIP              NaN                                                NaN
# SHV      20599980032  The fund will invest at least 80% of its asset...

# %%
STARTDATE = '2011-01-01'
ENDDATE = '2025-05-31'

tickers = list(info.index.values)
df = yf.download(tickers, start=STARTDATE, end=ENDDATE)['Close']
# Out:
# /var/folders/5y/9gbrlsgx0sn17yw7ydqrny4h0000gn/T/ipykernel_87833/1766415481.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(tickers, start=STARTDATE, end=ENDDATE)['Close']
# [*********************100%***********************]  12 of 12 completed

# %%
prices = df.resample('M').last()

# eliminate timezones
prices.index = prices.index.tz_localize(None)

rets = prices.pct_change().dropna()
rets['SHV'] -= .01/20

# change to excess returns, in excess of short-term treasury
retsx = rets.subtract(rets['SHV'], axis=0)
retsx = retsx.drop(columns=['SHV'])
# Out:
# /var/folders/5y/9gbrlsgx0sn17yw7ydqrny4h0000gn/T/ipykernel_87833/1814017950.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   prices = df.resample('M').last()

# %%
rets
# Out:
# Ticker           BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2011-02-28  0.006617  0.041710 -0.000437  0.035498  0.014355 -0.002084
# 2011-03-31  0.008427  0.026582  0.062896 -0.023883  0.000425 -0.001546
# 2011-04-30  0.048805  0.045559  0.027327  0.056258  0.015975  0.018413
# 2011-05-31 -0.013546 -0.051724 -0.029400 -0.022061  0.001333  0.025056
# 2011-06-30 -0.000097 -0.042645 -0.009355 -0.012107 -0.005706 -0.005044
# ...              ...       ...       ...       ...       ...       ...
# 2025-01-31  0.000935  0.027596  0.021521  0.048009  0.013605  0.006166
# 2025-02-28  0.013991  0.001366  0.011470  0.029531  0.009703  0.027997
# 2025-03-31  0.010353  0.022727  0.011340  0.001839 -0.010858  0.003419
# 2025-04-30  0.057697 -0.085778  0.001373  0.036951  0.001172  0.010561
# 2025-05-31 -0.004599  0.015070  0.040219  0.047906  0.017532 -0.012396
#
# Ticker           IYR       PSP       QAI       SHV       SPY       TIP
# Date
# 2011-02-28  0.045203  0.040146  0.002583 -0.000409  0.034737  0.007208
# 2011-03-31 -0.010934  0.016667  0.005521 -0.000328  0.000120  0.011903
# 2011-04-30  0.046632  0.058671  0.019034  0.000044  0.028962  0.023780
# 2011-05-31  0.010134 -0.041565  0.000000 -0.000600 -0.011214  0.002659
# 2011-06-30 -0.031060 -0.042581 -0.010776 -0.000328 -0.016870  0.007549
# ...              ...       ...       ...       ...       ...       ...
# 2025-01-31  0.018913  0.067995  0.016237  0.003133  0.026856  0.013703
# 2025-02-28  0.037861 -0.040107 -0.005952  0.002615 -0.012695  0.021572
# 2025-03-31 -0.023382 -0.060826 -0.013237  0.002843 -0.055719  0.006797
# 2025-04-30 -0.021514 -0.006867 -0.002555  0.002989 -0.008670  0.001259
# 2025-05-31  0.009072  0.044633  0.019212  0.002697  0.062845 -0.006319
#
# [172 rows x 12 columns]

# %%
retsx
# Out:
# Ticker           BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2011-02-28  0.007026  0.042120 -0.000027  0.035907  0.014764 -0.001675
# 2011-03-31  0.008755  0.026909  0.063224 -0.023555  0.000752 -0.001218
# 2011-04-30  0.048761  0.045515  0.027283  0.056214  0.015931  0.018369
# 2011-05-31 -0.012946 -0.051124 -0.028800 -0.021461  0.001933  0.025656
# 2011-06-30  0.000231 -0.042317 -0.009027 -0.011780 -0.005379 -0.004716
# ...              ...       ...       ...       ...       ...       ...
# 2025-01-31 -0.002198  0.024463  0.018388  0.044877  0.010472  0.003033
# 2025-02-28  0.011376 -0.001250  0.008855  0.026916  0.007087  0.025382
# 2025-03-31  0.007510  0.019885  0.008497 -0.001004 -0.013701  0.000577
# 2025-04-30  0.054708 -0.088766 -0.001616  0.033962 -0.001817  0.007573
# 2025-05-31 -0.007297  0.012373  0.037522  0.045208  0.014835 -0.015093
#
# Ticker           IYR       PSP       QAI       SPY       TIP
# Date
# 2011-02-28  0.045612  0.040555  0.002992  0.035147  0.007617
# 2011-03-31 -0.010607  0.016994  0.005848  0.000448  0.012231
# 2011-04-30  0.046588  0.058627  0.018990  0.028918  0.023736
# 2011-05-31  0.010733 -0.040965  0.000600 -0.010615  0.003259
# 2011-06-30 -0.030732 -0.042253 -0.010448 -0.016542  0.007877
# ...              ...       ...       ...       ...       ...
# 2025-01-31  0.015780  0.064862  0.013104  0.023723  0.010570
# 2025-02-28  0.035246 -0.042722 -0.008567 -0.015310  0.018957
# 2025-03-31 -0.026225 -0.063669 -0.016079 -0.058562  0.003955
# 2025-04-30 -0.024503 -0.009856 -0.005544 -0.011659 -0.001729
# 2025-05-31  0.006375  0.041936  0.016515  0.060147 -0.009016
#
# [172 rows x 11 columns]

# %%
with pd.ExcelWriter('../data/multi_asset_etf_data.xlsx') as writer:  
    info.to_excel(writer, sheet_name= 'descriptions')
    prices.to_excel(writer, sheet_name= 'prices')
    rets.to_excel(writer, sheet_name='total returns')
    retsx.to_excel(writer, sheet_name='excess returns')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 with pd.ExcelWriter('../data/multi_asset_etf_data.xlsx') as writer:
#       2     info.to_excel(writer, sheet_name= 'descriptions')
#       3     prices.to_excel(writer, sheet_name= 'prices')
#
# File ~/Documents/UChicago/Summer 2025/FINM 25000/finm-25000-a4-repository/.venv/lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)     55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)     66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'
